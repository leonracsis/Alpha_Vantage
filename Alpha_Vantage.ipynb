# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
ts = TimeSeries(key='V1EADLH4Z7Y7KA22',output_format='pandas')
#data, meta_data = ts.get_intraday(symbol='NYSE:URI',interval='1min', outputsize='full')
#print(data)
#data['4. close'].plot()
#plt.title('Intraday TimeSeries')
#plt.show()
import pandas as pd

# %%
URI_data, metadata=ts.get_daily('URI',outputsize='full')

# %%
URI_data.describe()
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  5420.000000  5420.000000  5420.000000  5420.000000  5.420000e+03
# mean     45.436751    46.146853    44.674673    45.410037  1.280341e+06
# std      42.323704    42.849282    41.759015    42.296015  1.373596e+06
# min       3.060000     3.300000     2.520000     3.030000  2.900000e+03
# 25%      17.767500    18.070000    17.400000    17.750000  4.383750e+05
# 50%      25.500000    25.995000    25.130000    25.535000  9.877500e+05
# 75%      63.055000    64.113750    61.727500    63.052500  1.666300e+06
# max     189.400000   190.740000   186.110000   189.400000  3.640930e+07

# %%
HRI_data, metadata=ts.get_daily('HRI',outputsize='full')

# %%
HRI_data
# Out:
#             1. open  2. high   3. low  4. close   5. volume
# date
# 2006-11-16    15.00  15.7800  14.9000    15.720  36124600.0
# 2006-11-17    15.72  15.9000  15.2500    15.660   4651800.0
# 2006-11-20    15.65  16.2200  15.5500    16.100   4437100.0
# 2006-11-21    16.10  16.2100  15.6000    15.610   2301700.0
# 2006-11-22    15.73  15.8500  15.4000    15.410   1792200.0
# 2006-11-24    15.12  15.3000  15.1000    15.240    555600.0
# 2006-11-27    15.05  15.1000  14.5500    14.750   3364100.0
# 2006-11-28    14.90  15.0100  14.6500    15.000   1805800.0
# 2006-11-29    15.00  15.1800  14.9000    15.170   1086600.0
# 2006-11-30    15.16  16.1000  15.1500    16.000   2668700.0
# 2006-12-01    15.85  15.9500  15.4000    15.910    792800.0
# 2006-12-04    15.75  15.7800  15.4500    15.660   1598000.0
# 2006-12-05    15.65  15.7900  15.5700    15.620    593900.0
# 2006-12-06    15.50  15.5700  15.3000    15.560   1917100.0
# 2006-12-07    15.55  15.7000  15.5400    15.600    866000.0
# ...

# %%
DJI_data, metadata=ts.get_daily('DJI',outputsize='full')

# %%
CAT_data, metadata=ts.get_daily('CAT',outputsize='full')

# %%
df['DJI']=DJI_data['4. close']

# %%
df=pd.DataFrame()

# %%
df['URI']=URI_data['4. close']

# %%
df.set_index(URI_data.index, inplace=True)

# %%
df.head()
# Out:
#               URI
# date
# 1998-01-02  20.06
# 1998-01-05  18.81
# 1998-01-06  19.38
# 1998-01-07  18.88
# 1998-01-08  18.44

# %%
CAT_data.describe()
# Out:
#            1. open      2. high       3. low     4. close     5. volume
# count  5420.000000  5420.000000  5420.000000  5420.000000  5.420000e+03
# mean     76.088206    76.924434    75.162257    76.061813  5.094527e+06
# std      28.205203    28.359903    28.019352    28.197135  4.029865e+06
# min      22.650000    23.290000    21.710000    22.170000  3.062000e+05
# 25%      53.990000    54.507500    53.137500    53.917500  2.270375e+06
# 50%      73.760000    74.605000    72.875000    73.745000  4.168052e+06
# 75%      91.400000    92.092500    90.282500    91.390000  6.641355e+06
# max     173.100000   173.240000   169.225100   170.890000  6.778040e+07

# %%
df['CAT']=CAT_data['4. close']

# %%
df['HRI']=HRI_data['4. close']

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3187 entries, 2006-11-16 to 2019-07-18
# Data columns (total 3 columns):
# URI    3187 non-null float64
# CAT    3187 non-null float64
# HRI    3187 non-null float64
# dtypes: float64(3)
# memory usage: 99.6+ KB

# %%
df[['URI','CAT','HRI']].plot(figsize=(16, 9))

# %%
df.corr()
# Out:
#           URI       CAT       HRI       DJI
# URI  1.000000  0.829052  0.913288  0.950976
# CAT  0.829052  1.000000  0.819788  0.832177
# HRI  0.913288  0.819788  1.000000  0.880071
# DJI  0.950976  0.832177  0.880071  1.000000

# %%
df.to_csv('stock.csv')
